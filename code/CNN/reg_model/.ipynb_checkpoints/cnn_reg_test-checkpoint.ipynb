# %%
BASE_DIR='../'*3
REG_DIR = BASE_DIR + 'code/CNN/reg_model/cnn_reg_model.ipynb'
FLW_DIR = BASE_DIR+'code/util/dataset/dataset_flowers.ipynb'
OFC_DIR = BASE_DIR+'code/util/dataset/dataset_office31.ipynb'

# %%
# %run {REG_DIR}
# %run {FLW_DIR}
# %run {OFC_DIR}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Documents\program\nalcoding\nalcoding\code\util\dataset\dataset_flowers.ipynb in <module>
#      26     self.shuffle_data(xs, ys, 0.8)
#      27
# ---> 28 FlowersDataset.__init__ = flowers_init
#
# NameError: name 'FlowersDataset' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12120/3647847496.py in <module>
#       1 get_ipython().run_line_magic('run', '{REG_DIR}')
# ----> 2 get_ipython().run_line_magic('run', '{FLW_DIR}')
#       3 # %run {OFC_DIR}
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     722             with preserve_keys(self.shell.user_ns, '__file__'):
#     723                 self.shell.user_ns['__file__'] = filename
# --> 724                 self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     725             return
#     726
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2833                     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2834                     if raise_exceptions:
# -> 2835                         result.raise_error()
#    2836                     elif not result.success:
#    2837                         break
#
# ~\anaconda3\envs\nalcoding\lib\site-packages\IPython\core\interactiveshell.py in raise_error(self)
#     329             raise self.error_before_exec
#     330         if self.error_in_exec is not None:
# --> 331             raise self.error_in_exec
#     332
#     333     def __repr__(self):
#
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_12120/598706954.py in <module>
#      26     self.shuffle_data(xs, ys, 0.8)
#      27
# ---> 28 FlowersDataset.__init__ = flowers_init
#
# NameError: name 'FlowersDataset' is not defined

# %%
fd = FlowersDataset([96, 96], [96, 96, 3])
od = Office31Dataset([96, 96], [96, 96, 3])

# %%
fm1 = CnnRegModel('flowers_model_1', fd, [30,10])
fm1.exec_all(epoch_count=10, report=2, show_params=True)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.460, accuracy=0.320/0.360 (77/77 secs)
#     Epoch 4: cost=1.467, accuracy=0.313/0.330 (75/152 secs)
#     Epoch 6: cost=1.431, accuracy=0.348/0.310 (77/229 secs)
#     Epoch 8: cost=1.457, accuracy=0.326/0.300 (76/305 secs)
#     Epoch 10: cost=1.403, accuracy=0.358/0.240 (77/382 secs)
# Model flowers_model_1 train ended in 382 secs:
# Model flowers_model_1 test report: accuracy = 0.311, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [15,23,14,25,22] => 추정 sunflower : 정답 daisy => X
# 추정확률분포 [15,23,14,25,22] => 추정 sunflower : 정답 sunflower => O
# 추정확률분포 [15,23,14,25,22] => 추정 sunflower : 정답 tulip => X
# Near 0 parameters =  0.0%(192/829790)

# %%
fm2 = CnnRegModel('flowers_model_2', fd, [30,10], l2_decay=0.1)
fm2.exec_all(epoch_count=10, show_cnt=0, show_params=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7028/1757627232.py in <module>
#       1 fm2 = CnnRegModel('flowers_model_2', fd, [30,10], l2_decay=0.1)
# ----> 2 fm2.exec_all(epoch_count=10, show_cnt=0, show_params=True)
#
# ~\AppData\Local\Temp/ipykernel_7028/625900685.py in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt, show_params)
#       9                  report=0, show_cnt=3, show_params=False):
#      10         super(CnnRegModel, self).exec_all(epoch_count, batch_size,
# ---> 11                                      learning_rate, report, show_cnt)
#      12         if show_params: self.show_param_dist()
#
# ~\AppData\Local\Temp/ipykernel_7028/766389791.py in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt)
#      11     def exec_all(self, epoch_count=10, batch_size=10, learning_rate=0.001,
#      12                  report=0, show_cnt=3):
# ---> 13         self.train(epoch_count, batch_size, learning_rate, report)
#      14         self.test()
#      15         if show_cnt > 0: self.visualize(show_cnt)
#
# ~\AppData\Local\Temp/ipykernel_7028/751064233.py in mlp_model_train(self, epoch_count, batch_size, learning_rate, report)
#      14         for n in range(batch_count):
#      15             trX, trY = self.dataset.get_train_data(batch_size, n)
# ---> 16             cost, acc = self.train_step(trX, trY)
#      17             costs.append(cost)
#      18             accs.append(acc)
#
# ~\AppData\Local\Temp/ipykernel_7028/1954470691.py in mlp_train_step(self, x, y)
#       3
#       4     output, aux_nn = self.forward_neuralnet(x)
# ----> 5     loss, aux_pp = self.forward_postproc(output, y)
#       6     accuracy = self.eval_accuracy(x, y, output)
#       7
#
# ~\AppData\Local\Temp/ipykernel_7028/3295751374.py in mlp_forward_postproc(self, output, y)
#       1 def mlp_forward_postproc(self, output, y):
#       2     loss, aux_loss = self.dataset.forward_postproc(output, y)
# ----> 3     extra, aux_extra = self.forward_extra_cost(y)
#       4     return loss + extra, [aux_loss, aux_extra]
#       5
#
# KeyboardInterrupt:

# %%
fm3 = CnnRegModel('flowers_model_3', fd, [30,10], l1_decay=0.01)
fm3.exec_all(epoch_count=10, show_cnt=0, show_params=True)

# %%
cnn1 = [['conv',{'ksize':3, 'chn':6}],
        ['max',{'stride':2}],
        ['conv',{'ksize':3, 'chn':12}],
        ['max',{'stride':2}],
        ['conv',{'ksize':3, 'chn':24}],
        ['avg',{'stride':3}]]
fcnn1 = CnnRegModel('flowers_cnn_1', fd, cnn1)
fcnn1.exec_all(epoch_count=10, report=2)

# %%
cnn2 = [['conv',{'ksize':3, 'chn':6}],
        ['max',{'stride':2}],
        ['dropout', {'keep_prob':0.6}],
        ['conv',{'ksize':3, 'chn':12}],
        ['max',{'stride':2}],
        ['dropout', {'keep_prob':0.6}],
        ['conv',{'ksize':3, 'chn':24}],
        ['avg',{'stride':3}],
        ['dropout', {'keep_prob':0.6}]]
fcnn2 = CnnRegModel('flowers_cnn_2', fd, cnn2)
fcnn2.exec_all(epoch_count=10, report=2, show_cnt=0)

# %%
noise_std = 0.01
cnn3 = [['noise', {'type':'normal','mean':0,'std':noise_std}],
        ['conv',{'ksize':3, 'chn':6}],
        ['max',{'stride':2}],
        ['noise', {'type':'normal','mean':0,'std':noise_std}],
        ['conv',{'ksize':3, 'chn':12}],
        ['max',{'stride':2}],
        ['noise', {'type':'normal','mean':0,'std':noise_std}],
        ['conv',{'ksize':3, 'chn':24}],
        ['avg',{'stride':3}]]
fcnn3 = CnnRegModel('flowers_cnn_3', fd, cnn3)
fcnn3.exec_all(epoch_count=10, report=2, show_cnt=0)

# %%
cnn4 = [['batch_normal'],
        ['conv',{'ksize':3, 'chn':6}],
        ['max',{'stride':2}],
        ['batch_normal'],
        ['conv',{'ksize':3, 'chn':12}],
        ['max',{'stride':2}],
        ['batch_normal'],
        ['conv',{'ksize':3, 'chn':24}],
        ['avg',{'stride':3}]]
fcnn4 = CnnRegModel('flowers_cnn_4', fd, cnn4)
fcnn4.exec_all(epoch_count=10, report=2, show_cnt=0)

# %%
ocnn1 = CnnRegModel('office31_cnn_1', od, cnn1)
ocnn2 = CnnRegModel('office31_cnn_2', od, cnn2)
ocnn3 = CnnRegModel('office31_cnn_3', od, cnn3)
ocnn4 = CnnRegModel('office31_cnn_4', od, cnn4)

ocnn1.exec_all(epoch_count=10, show_cnt=0)
ocnn2.exec_all(epoch_count=10, show_cnt=0)
ocnn3.exec_all(epoch_count=10, show_cnt=0)
ocnn4.exec_all(epoch_count=10, show_cnt=0)
