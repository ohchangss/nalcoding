# %%
BASE_DIR = '../'*3
RUN_DIR = BASE_DIR + 'code/RNN/rnn_ext_model/rnn_ext_model.ipynb'
DATA_DIR = BASE_DIR + 'code/RNN/rnn_ext_model/dataset_videoshot.ipynb'

# %%
# %run {RUN_DIR}
# %run {DATA_DIR}

# %%
vsd  = VideoShotDataset(['AStarIsBorn1937.mp4'])
print(vsd)
# Out:
# AStarIsBorn1937.mp4: cache file is found => use cache
# Creating thumbnail cache is done
# videoshot(binary, 400 frames, 100.0 shots, 2000 train_data)

# %%
conf1 = \
    [['seqwrap', ['avg',{'stride':30}],
                 ['conv',{'ksize':3, 'chn':12}],
                 ['full', {'width':16}]],
    ['lstm', {'recur_size':8}]]
    
vsm1 = RnnExtModel('vsm1', vsd, conf1)
vsm1.exec_all(epoch_count=10, report=2, show_cnt=3)
# Out:
# Model vsm1 train started:
#     Epoch 2: cost=0.667, accuracy=0.615/0.610 (50/50 secs)
#     Epoch 4: cost=0.662, accuracy=0.626/0.562 (48/98 secs)
#     Epoch 6: cost=0.660, accuracy=0.627/0.637 (47/145 secs)
#     Epoch 8: cost=0.657, accuracy=0.624/0.598 (49/194 secs)
#     Epoch 10: cost=0.586, accuracy=0.669/0.718 (53/247 secs)
# Model vsm1 train ended in 247 secs:
# Model vsm1 test report: accuracy = 0.756, (1 secs)
#
# Model vsm1 Visualization
# Est: 0.49,0.47,0.76,0.82
# Ans: 0.00,0.00,1.00,1.00
# Est: 0.48,0.43,0.42,0.77
# Ans: 0.00,0.00,0.00,1.00
# Est: 0.46,0.46,0.45,0.45
# Ans: 0.00,1.00,1.00,0.00

# %%
vsd.set_timesteps(6)

vsm1_6 = RnnExtModel('vsm1_6', vsd, conf1)
vsm1_6.exec_all(epoch_count=10, report=2, show_cnt=3)

vsd.set_timesteps(5)
# Out:
# Model vsm1_6 train started:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12628/715656108.py in <module>
#       2
#       3 vsm1_6 = RnnExtModel('vsm1_6', vsd, conf1)
# ----> 4 vsm1_6.exec_all(epoch_count=10, report=2, show_cnt=3)
#       5
#       6 vsd.set_timesteps(5)
#
# ~\AppData\Local\Temp/ipykernel_12628/625900685.py in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt, show_params)
#       9                  report=0, show_cnt=3, show_params=False):
#      10         super(CnnRegModel, self).exec_all(epoch_count, batch_size,
# ---> 11                                      learning_rate, report, show_cnt)
#      12         if show_params: self.show_param_dist()
#
# ~\AppData\Local\Temp/ipykernel_12628/766389791.py in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt)
#      11     def exec_all(self, epoch_count=10, batch_size=10, learning_rate=0.001,
#      12                  report=0, show_cnt=3):
# ---> 13         self.train(epoch_count, batch_size, learning_rate, report)
#      14         self.test()
#      15         if show_cnt > 0: self.visualize(show_cnt)
#
# ~\AppData\Local\Temp/ipykernel_12628/751064233.py in mlp_model_train(self, epoch_count, batch_size, learning_rate, report)
#      14         for n in range(batch_count):
#      15             trX, trY = self.dataset.get_train_data(batch_size, n)
# ---> 16             cost, acc = self.train_step(trX, trY)
#      17             costs.append(cost)
#      18             accs.append(acc)
#
# ~\AppData\Local\Temp/ipykernel_12628/1954470691.py in mlp_train_step(self, x, y)
#       8     G_loss = 1.0
#       9     G_output = self.backprop_postproc(G_loss, aux_pp)
# ---> 10     self.backprop_neuralnet(G_output, aux_nn)
#      11
#      12     self.is_training = False
#
# ~\AppData\Local\Temp/ipykernel_12628/2506643630.py in rnn_ext_backprop_neuralnet(self, G_output, aux)
#      17     for n in reversed(range(len(self.hconfigs))):
#      18         hconfig, pm, aux = self.hconfigs[n], self.pm_hiddens[n], aux_layers[n]
# ---> 19         G_hidden = self.backprop_layer(G_hidden, hconfig, pm, aux)
#      20
#      21     return G_hidden
#
# ~\AppData\Local\Temp/ipykernel_12628/3206124564.py in cnn_basic_backprop_layer(self, G_y, hconfig, pm, aux)
#       4     m_name = 'backprop_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     G_input = method(G_y, hconfig, pm, aux)
#       7
#       8     return G_input
#
# ~\AppData\Local\Temp/ipykernel_12628/4000225044.py in rnn_ext_backprop_seqwrap_layer(self, G_y, hconfig, pm, aux)
#       1 def rnn_ext_backprop_seqwrap_layer(self, G_y, hconfig, pm, aux):
# ----> 2     mb_size, timesteps1, rest = G_y.shape
#       3     lengths, x_shape, h_shape, aux_layers = aux
#       4
#       5     G_y_body = G_y.reshape([mb_size, timesteps1, -1])[:, 1:, :]
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
conf2 = \
    [['seqwrap', ['avg',{'stride':30}],
                 ['conv',{'ksize':3, 'chn':12}],
                 ['full', {'width':16}]],
    ['lstm', {'recur_size':8}],
    ['lstm', {'recur_size':4}]]
    
vsm2 = RnnExtModel('vsm2', vsd, conf2)
vsm2.exec_all(epoch_count=10, report=2, show_cnt=3)

# %%
conf3 = \
    [['seqwrap', ['conv',{'ksize':1, 'chn':4}],
                 ['max',{'stride':2}],
                 ['conv',{'ksize':1, 'chn':8}],
                 ['max',{'stride':3}],
                 ['conv',{'ksize':1, 'chn':16}],
                 ['avg',{'stride':5}],
                 ['full', {'width':12}]],
    ['lstm', {'recur_size':8}]]
    
vsm3 = RnnExtModel('vsm3', vsd, conf3)
vsm3.exec_all(epoch_count=10, report=2, show_cnt=3)

# %%
vsm1.exec_all(epoch_count=40, report=20, show_cnt=0)
vsm2.exec_all(epoch_count=40, report=20, show_cnt=0)
vsm3.exec_all(epoch_count=40, report=20, show_cnt=0)
